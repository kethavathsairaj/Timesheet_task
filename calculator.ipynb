# %%
while True:
    try:
        num1=float(input("enter the first value:"))
        num2=float(input("enter the second value:"))
    except valueError:
        print("invalid input!please enter the numeric values.")
        continue
    print("\nselect operator")
    print("1.addition")
    print("2.subtaction")
    print("3.multiplication")
    print("4.division")
    choice=input("select choice(1/2/3/4):")
    if choice not in['1','2','3','4']:
        print("invalid choice!try again.")
        continue
    if choice=="1":
        result=num1+num2
    elif choice=="2":
        result=num1-num2
    elif choice=="3":
        result=num1*num2
    elif choice=="4":
        if num2==0:
            print("Error! division by zero not allowed.")
            continue
        result=num1/num2
    print("result:",result)
    again=input("do you want to continue?(yes/no):")
    if again.lower()!="yes":
        print("calculator closed")
        break
# Out:
# select operator
# 1.addition
# 2.subtaction
# 3.multiplication
# 4.division
# result: 22.0
#
# select operator
# 1.addition
# 2.subtaction
# 3.multiplication
# 4.division
# result: 32.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 29
#      27     result=num1/num2
#      28 print("result:",result)
# ---> 29 again=input("do you want to continue?(yes/no):")
#      30 if again.lower()!="yes":
#      31     print("calculator closed")
#
# File ~/Library/Python/3.14/lib/python/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/Library/Python/3.14/lib/python/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
